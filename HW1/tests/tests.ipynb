# %%
import test_unconstrained_min
# Out:
# 1
# Choose a function for analysis from the following:
# 1-circle, 2-ellipse, 3-shifted ellipse, 4-Rosenbrock, 5-linear, 6-nonquad
# 1
# You chose 5: linear
# The chosen method is = gd
# Gradient Descent: iteration = 1,  position = [8. 6.], objective function value = 14.0 :
#  Backtrack: step_length = 1.0, func_value_current = 14.0, func_value_next = 12.0, grad_proj_step_diff = 0.0002 :
# Gradient Descent: iteration = 2,  position = [7. 5.], objective function value = 12.0 :
#  Backtrack: step_length = 1.0, func_value_current = 12.0, func_value_next = 10.0, grad_proj_step_diff = 0.0002 :
# Gradient Descent: iteration = 3,  position = [6. 4.], objective function value = 10.0 :
#  Backtrack: step_length = 1.0, func_value_current = 10.0, func_value_next = 8.0, grad_proj_step_diff = 0.0002 :
# Gradient Descent: iteration = 4,  position = [5. 3.], objective function value = 8.0 :
# ...
