# %%
import test_unconstrained_min
# Out:
# ok
# ok
# ok2
# ok3
# 1
# Choose a function for analysis from the following:
# 1-circle, 2-ellipse, 3-shifted ellipse, 4-Rosenbrock, 5-linear, 6-nonquad
# 1
# You chose 3: shifted ellipse
# The chosen method is = gd
# Gradient Descent: iteration = 1,  position = [8. 6.], objective function value = 1627.6472812163474 :
#  Backtrack: step_length = 0.00390625, func_value_current = 1627.6472812163474, func_value_next = 157.0916833425954, grad_proj_step_diff = 0.24123808656695483 :
# Gradient Descent: iteration = 2,  position = [5.30632457 7.47223484], objective function value = 157.0916833425954 :
#  Backtrack: step_length = 0.00390625, func_value_current = 157.0916833425954, func_value_next = 85.49053745294177, grad_proj_step_diff = 0.011667379091953903 :
# Gradient Descent: iteration = 3,  position = [4.68929928 7.74616329], objective function value = 85.49053745294177 :
# ...
