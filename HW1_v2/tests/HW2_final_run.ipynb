# %%
import unittest
import test_constrained_min
from HW1_v2.tests.test_constrained_min import TestConstrainedMinimization

# Create a test suite
suite = unittest.TestLoader().loadTestsFromTestCase(TestConstrainedMinimization)

# Create a test runner
runner = unittest.TextTestRunner()

# Run the test suite
result = runner.run(suite)

# Check the test result
if result.wasSuccessful():
    print("All tests passed!")
else:
    print("Some tests failed.")
# Out:
# Barrier init: x = [0.5  0.75], f(x) = -1.25, m/t = 4.0
# Barrier iteration #0: x = [1.46285357 0.69672008], f(x) = -2.1595736488296318, m/t = 4.0
# Barrier iteration #1: x = [1.9051114  0.91403322], f(x) = -2.819144619723565, m/t = 0.4
# Barrier iteration #2: x = [1.9899595  0.99005958], f(x) = -2.980019076002479, m/t = 0.04
# Barrier iteration #3: x = [1.99891566 0.99891675], f(x) = -2.9978324106590093, m/t = 0.004
# Barrier iteration #4: x = [1.99984547 0.99984548], f(x) = -2.9996909529079043, m/t = 0.0004
# Barrier iteration #5: x = [1.99996881 0.9999688 ], f(x) = -2.9999376108314997, m/t = 4e-05
# .
# Barrier init: x = [0.1 0.2 0.7], f(x) = 2.9399999999999995, m/t = 4.0
# Barrier iteration #0: x = [0.19607843 0.37037037 0.21212121], f(x) = 1.6448587953720013, m/t = 4.0
# Barrier iteration #1: x = [ 0.2236068   0.22360058 -1.04244803], f(x) = 0.10179905642643343, m/t = 0.4
# Barrier iteration #2: x = [ 0.04065578  0.04065671 -1.00496885], f(x) = 0.0033305497244334394, m/t = 0.04
# Barrier iteration #3: x = [ 0.01888426  0.01888403 -1.00049974], f(x) = 0.0007134715568014837, m/t = 0.004
# Barrier iteration #4: x = [ 0.01888426  0.01888403 -1.00049974], f(x) = 0.0007134715568014837, m/t = 0.0004
# Barrier iteration #5: x = [ 0.01888426  0.01888403 -1.00049974], f(x) = 0.0007134715568014837, m/t = 4e-05
# .
# ----------------------------------------------------------------------
# Ran 2 tests in 7.183s
#
# OK
# All tests passed!
