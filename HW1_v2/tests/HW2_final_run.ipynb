# %%
import unittest
import test_constrained_min
from HW1_v2.tests.test_constrained_min import TestConstrainedMin

# Create a test suite
suite = unittest.TestLoader().loadTestsFromTestCase(TestConstrainedMin)

# Create a test runner
runner = unittest.TextTestRunner()

# Run the test suite
result = runner.run(suite)

# Check the test result
if result.wasSuccessful():
    print("All tests passed!")
else:
    print("Some tests failed.")
# Out:
# Iteration: 0 	 x = [0.1 0.2 0.7], f(x) = 2.9400, gap = 3.0000
# [-9.8        -4.6         1.97142857]
#     Iteration2: 1 	 x = [0.20345446 0.39823537 0.39831017], p_nt=[ 0.10345446  0.19823537 -0.30168983], np.linalg.norm(p_nt) > eps=True
# [-4.5081959  -1.7146071   0.28601412]
#     Iteration2: 2 	 x = [0.32862732 0.45611439 0.21525829], p_nt=[ 0.12517286  0.05787902 -0.18305188], np.linalg.norm(p_nt) > eps=True
# [-2.38570599 -1.2802037  -2.21506523]
#     Iteration2: 3 	 x = [0.38279946 0.38331249 0.23388805], p_nt=[ 0.05417214 -0.0728019   0.01862976], np.linalg.norm(p_nt) > eps=True
# [-1.84673498 -1.84221251 -1.80777367]
#     Iteration2: 4 	 x = [0.38379844 0.38379998 0.23240158], p_nt=[ 0.00099898  0.00048749 -0.00148647], np.linalg.norm(p_nt) > eps=True
# [-1.83793744 -1.83792391 -1.83809349]
#     Iteration2: 5 	 x = [0.38379594 0.38379594 0.23240812], p_nt=[-2.49846727e-06 -4.03806226e-06  6.53652953e-06], np.linalg.norm(p_nt) > eps=False
# ...

# %%
### Linear: 
import unittest
import test_constrained_min
from HW1_v2.tests.test_constrained_min import TestConstrainedMin

# Create a test suite
suite = unittest.TestLoader().loadTestsFromTestCase(TestConstrainedMin)

# Create a test runner
runner = unittest.TextTestRunner()

# Run the test suite
result = runner.run(suite)

# Check the test result
if result.wasSuccessful():
    print("All tests passed!")
else:
    print("Some tests failed.")
# Out:
# Iteration: 0 	 x = [0.5  0.75], f(x) = -1.2500, gap = 4.0000
# [-4.33333333 -2.33333333]
#     Iteration2: 1 	 x = [0.86411605 0.64660293], p_nt=[ 0.36411605 -0.10339707], np.linalg.norm(p_nt) > eps=True
# [-2.07765235 -1.67488994]
#     Iteration2: 2 	 x = [1.31892651 0.64176979], p_nt=[ 0.45481047 -0.00483314], np.linalg.norm(p_nt) > eps=True
# [-0.57264133 -0.80760177]
#     Iteration2: 3 	 x = [1.4768719  0.69807482], p_nt=[0.15794539 0.05630503], np.linalg.norm(p_nt) > eps=True
# [0.06047525 0.02846518]
#     Iteration2: 4 	 x = [1.46328418 0.69672009], p_nt=[-0.01358772 -0.00135473], np.linalg.norm(p_nt) > eps=True
# [ 1.11757928e-03 -7.84475738e-05]
#     Iteration2: 5 	 x = [1.46301542 0.69674043], p_nt=[-2.68754621e-04  2.03413623e-05], np.linalg.norm(p_nt) > eps=True
# [ 4.27666488e-07 -2.59522246e-08]
#     Iteration2: 6 	 x = [1.46301532 0.69674044], p_nt=[-1.02870564e-07  7.48952280e-09], np.linalg.norm(p_nt) > eps=False
# ...
